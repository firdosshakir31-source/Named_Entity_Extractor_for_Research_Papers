# %%
from transformers import pipeline

import matplotlib.pyplot as plt

classifier = pipeline("sentiment-analysis")

texts = [

    "The battery is amazing",

    "The screen is bad",

    "The camera is very good"

]

labels = []

for text in texts:

    result = classifier(text)[0]

    print(text, "->", result)



    if result['label'] == 'POSITIVE':

        labels.append("Positive")

    else:

        labels.append("Negative")

positive_count = labels.count("Positive")

negative_count = labels.count("Negative")

plt.figure()

plt.bar(["Positive", "Negative"], [positive_count, negative_count])

plt.title("Sentiment Analysis Results")

plt.xlabel("Sentiment")

plt.ylabel("Count")

plt.show()
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# The battery is amazing -> {'label': 'POSITIVE', 'score': 0.9998822212219238}
# The screen is bad -> {'label': 'NEGATIVE', 'score': 0.9998156428337097}
# The camera is very good -> {'label': 'POSITIVE', 'score': 0.999869704246521}
